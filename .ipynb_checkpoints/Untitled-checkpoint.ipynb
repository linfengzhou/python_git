# %%
import os

# %%
os.system("touch test.txt")
# Out:
# 0

# %%
os.system('echo "ass" >> text.txt')
# Out:
# 0

# %%
os.system('git add text.txt')
os.system('git commit -m "test"')
os.system('git push')
# Out:
# 0

# %%
os.system('git push')
# Out:
# 32768

# %%
import pandas as pd

# %%
import pexpect

# %%
a = pexpect.run('ls -la')

# %%
a
# Out:
# b'total 56\r\ndrwxrwxr-x  4 luke luke 4096 Mar 23 09:57 .\r\ndrwxrwxr-x 15 luke luke 4096 Mar 23 09:33 ..\r\ndrwxrwxr-x  8 luke luke 4096 Mar 23 09:51 .git\r\ndrwxr-xr-x  2 luke luke 4096 Mar 23 09:33 .ipynb_checkpoints\r\n-rw-rw-r--  1 luke luke   13 Mar 23 09:31 README.md\r\n-rw-rw-r--  1 luke luke   10 Mar 23 09:51 text.txt\r\n-rw-rw-r--  1 luke luke 3134 Mar 23 09:57 Untitled.ipynb\r\n'

# %%
from git import Repo
import os.path as osp

# %%
join = osp.join

# %%
join
# Out:
# <function posixpath.join>

# %%
repo = Repo("../python_git/")

# %%
git = repo.git

# %%
try:
    cloned_repo = repo.clone_from("https://github.com/linfengzhou/python_git.git","test/")
except:
    print('error!')
os.system('echo "ass" >> test/text.txt')
git.add("-A")
git.commit("-m new git")
git.push("https://linfengzhou:cs30e0001299+@github.com/linfengzhou/python_git.git")
# Out:
# error!
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# <ipython-input-70-2dd76219c1d4> in <module>()
#       4     print('error!')
#       5 os.system('echo "ass" >> test/text.txt')
# ----> 6 git.add("-A")
#       7 git.commit("-m new git")
#       8 git.push("https://linfengzhou:cs30e0001299+@github.com/linfengzhou/python_git.git")
#
# /usr/local/lib/python3.5/dist-packages/git/cmd.py in <lambda>(*args, **kwargs)
#     423         if name[0] == '_':
#     424             return LazyMixin.__getattr__(self, name)
# --> 425         return lambda *args, **kwargs: self._call_process(name, *args, **kwargs)
#     426
#     427     def set_persistent_git_options(self, **kwargs):
#
# /usr/local/lib/python3.5/dist-packages/git/cmd.py in _call_process(self, method, *args, **kwargs)
#     875         call.extend(args)
#     876
# --> 877         return self.execute(call, **exec_kwargs)
# ...

# %%
os.system('echo "ass" >> text.txt')

# %%
os.system('echo "assas" >>text.txt')
# Out:
# ''

# %%
pd.DataFrame({'Age':[3,2,1,0,-1,-2]}).to_csv('Data/Age/Age.csv',index=False)
pd.DataFrame({'Name':['lz','lz3','lz6','lz9','lz12','lz27']}).to_csv('Data/Name/Name.csv',index=False)

# %%
subfolderList = os.listdir("Data/")
for index, subfolder in enumerate(subfolderList):
#     print(subfolder)
    if index == 0:
        df = pd.read_csv("Data/"+subfolder+'/'+subfolder+'.csv')
    else:
        df1 = pd.read_csv("Data/"+subfolder+'/'+subfolder+'.csv')
        df = pd.concat([df,df1],axis=1)

# %%
df
# Out:
#    Age  Name
# 0    3    lz
# 1    2   lz3
# 2    1   lz6
# 3    0   lz9
# 4   -1  lz12
# 5   -2  lz27

# %%
def read_data(folder_name):
    subfolderList = os.listdir(folder_name)
    root_df = pd.DataFrame()
    files_dict = {}
    for subfolder in subfolderList:
        csvfiles = list(filter(lambda x: 'csv' in x,os.listdir("/".join([folder_name,subfolder]))))
        for index, file in enumerate(csvfiles):
            file_path = "/".join([folder_name,subfolder,file])
            if index == 0:
                df = pd.read_csv(file_path)
                files_dict[subfolder] = [file]
            else:
                df1 = pd.read_csv(file_path)
                df1_diff = df1.columns.difference(df.columns)
                df = pd.concat([df,df1[df1_diff]],axis=1) 
                files_dict[subfolder].append(file)
        df_diff = root_df.columns.difference(df.columns)
        root_df = pd.concat([root_df[df_diff], df], axis=1)
    return root_df,files_dict

# %%
def export_data(total_df,main_folder,files_dict):
    for subfolder in files_dict:
        for column in files_dict[subfolder]:
            column_name = column[:-4]
            file_path = "/".join([main_folder,subfolder,column])
            pd.DataFrame({'Sku':total_df['Sku'],column_name:total_df[column_name]}).to_csv(file_path,index=False)

# %%
def update_value(total_df, index, col_name, new_value):
    total_df.loc[index, col_name] = new_value
    return total_df

# %%
list(filter(lambda x: 'csv' in x,os.listdir("Data/Age/")))
# Out:
# ['NewAge.csv', 'Age.csv']

# %%
total_df,files_dict = read_data("Data")
print(total_df)
total_df = update_value(total_df, 1, 'NewName','LAOSIJI1')
print(total_df)
export_data(total_df,'Data/',files_dict)
# Out:
#      Age  NewAge      Name      Sku NewName
# 0      3     135        lz  p123456      lq
# 1      2      26  LAOSIJI1  p123457     lq1
# 2      1     450       lz6  p123458     llq
# 3  11136      58   LAOSIJI  p123459     lqq
# 4     36      51   LAOSIJI  p123460     qqq
# 5     36      56   LAOSIJI  p123461     lll
#      Age  NewAge      Name      Sku   NewName
# 0      3     135        lz  p123456        lq
# 1      2      26  LAOSIJI1  p123457  LAOSIJI1
# 2      1     450       lz6  p123458       llq
# 3  11136      58   LAOSIJI  p123459       lqq
# 4     36      51   LAOSIJI  p123460       qqq
# 5     36      56   LAOSIJI  p123461       lll

# %%
total_df.loc[4, 'Age'] = 12

# %%
total_df,files_dict = read_data("Data")

# %%
total_df
# Out:
#      Age  NewAge      Sku     Name NewName
# 0      3     135  p123456       lz      lq
# 1      2      26  p123457      lz3     lq1
# 2      1     450  p123458      lz6     llq
# 3  11136      58  p123459  LAOSIJI     lqq
# 4     36      51  p123460  LAOSIJI     qqq
# 5     36      56  p123461  LAOSIJI     lll

# %%
export_data(total_df,'Data/',files_dict)

# %%
total_df.columns.difference(total_df.drop('Sku',axis=1).columns)
# Out:
# Index(['Sku'], dtype='object')

# %%
try:
    cloned_repo = repo.clone_from("https://github.com/linfengzhou/python_git.git","test/")
except:
    git.pull()
os.system('echo "ass" >> test/text.txt')
git.add("-A")
git.commit("-m new git")
git.push("https://linfengzhou:cs30e0001299+@github.com/linfengzhou/python_git.git")
# Out:
# ''

# %%
# Out:
# 'Already up-to-date.'
